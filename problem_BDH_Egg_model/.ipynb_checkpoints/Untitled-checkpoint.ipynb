# %%
option_times = [1,2]
for i in option_times:
    # %run main.ipynb
# Out:
# Value of the initial investment: $180.0
# PV of cash flows: $398.3
# Net Present Value: $218.3
# CASH FLOW
# Value of the initial investment: $180.0
# PV of cash flows: $390.8
# Value of the project without options (NPV): $210.8
# Options times:   0%|          | 0/2 [00:00<?, ?time/s]
# Value of the initial investment: $180.0
# PV of cash flows: $454.2
# Value of the project with options (NPV): $274.2
# Option value: $63.3
# Value of the initial investment: $180.0
# PV of cash flows: $398.3
# Net Present Value: $218.3
# CASH FLOW
# Value of the initial investment: $180.0
# PV of cash flows: $391.2
# Value of the project without options (NPV): $211.2
# Options times:   0%|          | 0/2 [00:00<?, ?time/s]
# Value of the initial investment: $180.0
# PV of cash flows: $454.5
# Value of the project with options (NPV): $274.5
# Option value: $63.3
